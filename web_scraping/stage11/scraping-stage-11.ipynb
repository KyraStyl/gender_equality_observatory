# %% [markdown]
# # Web scraping
#
# Making the initial graph

# %% [markdown]
# Author csv structure:
# - name: string (full name)
# - id: int (Scholar id)
# - gender: M/F
# - affiliation: string
# - citedby: int
# - citedby5y: int
# - hindex: int
# - hindex5y: int
# - i10index: int
# - i10index5y: int
# - num_publications: int
# - citations: string, e.g. ... 2018-954 2019-1048 ...
# - interests: string, e.g. Wireless_Networks IoT
#
# Coauthor csv structure:
# - name: string (full name)
# - id: int (Scholar id)
#
# Edges csv structure:
# - name2name: string, e.g. Athena_Vakali George_Vlahavas

# %%
import json
import pandas as pd

# %%
authors = json.load(open('../stage10/uni_authors.json'))
coauthors = json.load(open('../stage9/coauthors.json'))

# %% [markdown]
# Set custom affiliation to authors

# %%
for uni in authors:
    for auth in uni['authors']:
        auth['affiliation'] = 'University of ' + uni['university'].capitalize()

# %%
authors_flat = []
for uni in authors:
    authors_flat += uni['authors']

# %%
len(authors_flat)
# Out:
# 340

# %%
author_df = pd.DataFrame(authors_flat)
author_df
# Out:
#        scholar_id                      name                 affiliation  \
# 0    72e5VYEAAAAJ         Steven M. LaValle          University of Oulu
# 1    9P2jyr8AAAAJ                Timo Ojala          University of Oulu
# 2    8aM6EeEAAAAJ              Jukka Riekki          University of Oulu
# 3    d4rhcDAAAAAJ           Denzil Ferreira          University of Oulu
# 4    lwakBbMAAAAJ        Georgi V. Georgiev          University of Oulu
# ..            ...                       ...                         ...
# 335  AiqUHA8AAAAJ       Athanasios Kehagias  University of Thessaloniki
# 336  TmGjsAoAAAAJ          George Sergiadis  University of Thessaloniki
# 337  YWalTEUAAAAJ   Dimitrios Chrissoulidis  University of Thessaloniki
# 338  FWPjh-AAAAAJ          Charis Demoulias  University of Thessaloniki
# 339  ITtvU8sAAAAJ  Vasilis Chatziathanasiou  University of Thessaloniki
#
#     gender                 role  \
# 0        M            Professor
# 1        M            Professor
# 2        M            Professor
# 3        M  Associate Professor
# 4        M  Associate Professor
# ..     ...                  ...
# 335      M  Associate Professor
# 336      M            Professor
# 337      M            Professor
# 338      M            Professor
# 339      M  Associate Professor
#
#                                            url_picture  \
# 0    https://scholar.google.com/citations?view_op=m...
# 1    https://scholar.google.com/citations?view_op=m...
# 2    https://scholar.google.com/citations?view_op=m...
# 3    https://scholar.google.com/citations?view_op=m...
# 4    https://scholar.google.com/citations?view_op=m...
# ..                                                 ...
# 335  https://scholar.google.com/citations?view_op=m...
# 336  https://scholar.google.com/citations?view_op=m...
# 337  https://scholar.google.com/citations?view_op=m...
# 338  https://scholar.google.com/citations?view_op=m...
# 339  https://scholar.google.com/citations?view_op=m...
#
#                                              coauthors  i10index  i10index5y  \
# 0    [1NyT9gQAAAAJ, CPze844AAAAJ, jkRa2LEAAAAJ, -JP...       158          91
# 1    [bjEpXBoAAAAJ, sxK1vQwAAAAJ, JnWGV4kAAAAJ, xFj...       110          60
# 2    [f-jBRoIAAAAJ, Ij_W2wsAAAAJ, GA4D9f8AAAAJ, 6Dd...       113          46
# 3    [JnWGV4kAAAAJ, SkQ6OisAAAAJ, ydA8Q5AAAAAJ, Qzl...        49          47
# 4    [nguLAo0AAAAJ, GA4D9f8AAAAJ, 8aM6EeEAAAAJ, J13...        10           7
# ..                                                 ...       ...         ...
# 335  [IxCZDBQAAAAJ, 0SQP4bwAAAAJ, 3RiPf3wAAAAJ, bo7...        48          21
# 336                                                 []        36          22
# 337                                                 []         7           3
# 338  [LIuIdj0AAAAJ, y6UkvosAAAAJ, bitSbpYAAAAJ, jY_...        33          25
# 339                                     [jY_JAmEAAAAJ]        13           9
#
#      hindex  hindex5y  citedby  citedby5y  num_publications  \
# 0        59        34    30593      12679               297
# 1        41        28    33500      16240               208
# 2        32        22     4011       1767               299
# 3        28        27     2981       2484               110
# 4        10         8      317        208               101
# ..      ...       ...      ...        ...               ...
# 335      29        15     2249        647               120
# 336      19        13     1867        921               108
# 337       8         5      216         73                32
# 338      19        18     1232        872                78
# 339      11         9      639        343                49
#
#                                              interests  \
# 0    [Virtual reality, robotics, sensor fusion, mot...
# 1    [Virtual reality, hybrid reality, ubiquitous c...
# 2    [edge computing, distributed artificial intell...
# 3    [Sensors and Instrumentation, Mobile and Ubiqu...
# 4    [design creativity, digital fabrication, idea ...
# ..                                                 ...
# 335  [Applied Mathematics, mathematical models, pro...
# 336                           [Biomedical Engineering]
# 337                                                 []
# 338                           [Electrical engineering]
# 339                                                 []
#
#                                         cites_per_year
# 0    {'1999': 100, '2000': 132, '2001': 196, '2002'...
# 1    {'2001': 92, '2002': 132, '2003': 145, '2004':...
# 2    {'2000': 15, '2001': 19, '2002': 7, '2003': 23...
# 3    {'2012': 36, '2013': 65, '2014': 135, '2015': ...
# 4    {'2007': 3, '2008': 1, '2009': 9, '2010': 11, ...
# ..                                                 ...
# 335  {'1995': 11, '1996': 17, '1997': 24, '1998': 3...
# 336  {'2004': 7, '2005': 6, '2006': 9, '2007': 43, ...
# 337  {'2000': 1, '2001': 3, '2002': 4, '2003': 7, '...
# 338  {'2001': 5, '2002': 6, '2003': 7, '2004': 9, '...
# 339  {'1994': 2, '1995': 3, '1996': 2, '1997': 3, '...
#
# [340 rows x 16 columns]

# %%
coauthor_df = pd.DataFrame(coauthors['successful'])
coauthor_df
# Out:
#         scholar_id                         name  \
# 0     stT2bnoAAAAJ              Gunther Eggeler
# 1     _bs1TE0AAAAJ             Lidija Petkovska
# 2     WWKtZZYAAAAJ                James Dedrick
# 3     C8Ir-n4AAAAJ                Finn Kuusisto
# 4     NlBmV2QAAAAJ                 João Saraiva
# ...            ...                          ...
# 2315  2vrAze8AAAAJ                 Marco Jacobs
# 2316  KLE-AyEAAAAJ                Jacques Robin
# 2317  J8tTJP8AAAAJ                 Irène Durand
# 2318  E1gfeiMAAAAJ  Themistoklis Diamantopoulos
# 2319  SB_7Bi0AAAAJ                Nitish Thakor
#
#                                             affiliation  \
# 0     Institute for Materials, Ruhr-University Bochu...
# 1     Professor of Electrical Machines and Drives, S...
# 2                                    University of York
# 3                                                 FANTM
# 4          HASLab / INESC TEC and Universidade do Minho
# ...                                                 ...
# 2315                            Marco Jacobs Consulting
# 2316               Université Paris 1 Panthéon-Sorbonne
# 2317                             University of Bordeaux
# 2318  Research Fellow at Aristotle University of The...
# 2319  Johns Hopkins University, National University ...
#
#                                             url_picture  i10index  i10index5y  \
# 0     https://scholar.googleusercontent.com/citation...       310         225
# 1     https://scholar.googleusercontent.com/citation...        15           5
# 2                                                               8           6
# 3     https://scholar.googleusercontent.com/citation...         7           7
# 4     https://scholar.googleusercontent.com/citation...        62          27
# ...                                                 ...       ...         ...
# 2315  https://scholar.googleusercontent.com/citation...         4           2
# 2316  https://scholar.googleusercontent.com/citation...        30           7
# 2317                                                           13           2
# 2318                                                            8           8
# 2319  https://scholar.googleusercontent.com/citation...       462         307
#
#       hindex  hindex5y  citedby  citedby5y  num_publications  \
# 0         72        49    21876      12366               742
# 1         11         7      689        243               148
# 2          9         8      246        193                56
# 3          7         7      143        127                32
# 4         27        18     2435       1085               205
# ...      ...       ...      ...        ...               ...
# 2315       5         3      232         72                27
# 2316      18         9     1387        231                69
# 2317      11         4      419         75                68
# 2318       9         9      227        208                44
# 2319      87        56    32382      14432              8073
#
#                                               coauthors
# 0     [W-52j5AAAAAJ, FrOUKW4AAAAJ, EGDi4BMAAAAJ, Qav...
# 1                                        [S-4AR8AAAAAJ]
# 2     [y_qoKAoAAAAJ, CcrxVa8AAAAJ, 9DnjXXkAAAAJ, xmt...
# 3     [okf5bmQAAAAJ, UMGysigAAAAJ, tFdKEgEAAAAJ, 0fA...
# 4     [b-zzik0AAAAJ, fYCE5-sAAAAJ, 7VPNqiEAAAAJ, EEe...
# ...                                                 ...
# 2315         [1FQwYvoAAAAJ, ni6owYQAAAAJ, 1Us1N7AAAAAJ]
# 2316  [ujDhg2sAAAAJ, Is0pLz0AAAAJ, _ZkpywYAAAAJ, 2Px...
# 2317                                                 []
# 2318  [339uVZQAAAAJ, zVNCDMsAAAAJ, KRG5Mg8AAAAJ, S3C...
# 2319  [_9Rp_a4AAAAJ, VX9dk3oAAAAJ, tz4TKL0AAAAJ, z33...
#
# [2320 rows x 12 columns]

# %% [markdown]
# Do we still have authors in coauthors?

# %%
common_names = set.intersection(set(coauthor_df['name']), set(author_df['name']))
common_names
# Out:
# {'Adam Wojciechowski'}

# %%
common_ids = set.intersection(set(coauthor_df['scholar_id']), set(author_df['scholar_id']))
common_ids
# Out:
# set()

# %% [markdown]
# Let's investigate.

# %%
author_df[author_df['name'] == 'Adam Wojciechowski']
# Out:
#        scholar_id                name         affiliation gender  \
# 229  mRiW0csAAAAJ  Adam Wojciechowski  University of Lodz      M
#
#                     role                                        url_picture  \
# 229  Associate Professor  https://scholar.google.com/citations?view_op=m...
#
#     coauthors  i10index  i10index5y  hindex  hindex5y  citedby  citedby5y  \
# 229        []         8           5       9         8      269        196
#
#      num_publications                                          interests  \
# 229                74  [human-computer interaction, computer graphics...
#
#                                         cites_per_year
# 229  {'2006': 4, '2007': 5, '2008': 4, '2009': 3, '...

# %%
coauthor_df[coauthor_df['name'] == 'Adam Wojciechowski']
# Out:
#        scholar_id                name                         affiliation  \
# 105  WBhGYE8AAAAJ  Adam Wojciechowski     Poznan University of Technology
# 368  g628b44AAAAJ  Adam Wojciechowski  Instytut Logistyki i Magazynowania
#
#     url_picture  i10index  i10index5y  hindex  hindex5y  citedby  citedby5y  \
# 105                    13           7      12         7      764        203
# 368                     3           3       5         5      208        107
#
#      num_publications coauthors
# 105                46        []
# 368               214        []

# %% [markdown]
# We will rename the Adam Wojciechowski coauthors to Adam Wojciechowski(2) and Adam Wojciechowski(3).

# %%
coauthor_df.at[105, 'name'] = 'Adam Wojciechowski(2)'
coauthor_df.at[368, 'name'] = 'Adam Wojciechowski(3)'

# %%
coauthor_df.loc[coauthor_df['scholar_id'] == 'WBhGYE8AAAAJ']['name'], coauthor_df.loc[coauthor_df['scholar_id'] == 'g628b44AAAAJ']['name']
# Out:
# (105    Adam Wojciechowski(2)
#  Name: name, dtype: object,
#  368    Adam Wojciechowski(3)
#  Name: name, dtype: object)

# %% [markdown]
# // TODO: Create csv 1 (authors), 2 (coauthors) and 3 (edges)
#
# For both coauthors and authors we will only discard the coauthor list. Images are good for the front-end.

# %% [markdown]
# // TODO: Create a README.md that will describe each stage shortly
